# %%
import os
import sys
from tqdm.notebook import tqdm
import numpy as np
from collections import Counter, defaultdict

from nltk.tokenize import sent_tokenize

# %%
import roberta_ses
from roberta_ses.interface import Roberta_SES_Entailment

# from sentence_transformers import SentenceTransformer

# import faiss

# %% [markdown]
# ## Entailment between sentences

# %%
### 0 = contradict, 1 = neutral, 2 = entailment

# %%
# ses = Roberta_SES_Entailment(
#     roberta_path='/Users/ytshao/Desktop/Yutong/models/roberta-large-mnli/',
#     ckpt_path='/Users/ytshao/Desktop/Yutong/external_repos/Roberta_SES/checkpoints/roberta-large/epoch=2-valid_loss=-0.2620-valid_acc_end=0.9223.ckpt',
#     max_length=512,
#     device_name='cpu')

ses = Roberta_SES_Entailment(
    roberta_path='/Users/ytshao/Desktop/Yutong/models/roberta-large/',
    ckpt_path='/Users/ytshao/Desktop/Yutong/external_repos/Roberta_SES/checkpoints/roberta-large/epoch=2-valid_loss=-0.2620-valid_acc_end=0.9223.ckpt',
    output_classes=3,
    max_length=512,
    device_name='cpu')

# ses = Roberta_SES_Entailment(
#     roberta_path='/Users/ytshao/Desktop/Yutong/models/roberta-base',
#     ckpt_path='/Users/ytshao/Desktop/Yutong/external_repos/Roberta_SES/checkpoints/roberta-base/epoch=4-valid_loss=-0.6472-valid_acc_end=0.9173.ckpt',
#     max_length=512,
#     device_name='cpu')

# %%
ses.model.bert_config
# Out:
# RobertaConfig {
#   "architectures": [
#     "RobertaForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 514,
#   "model_type": "roberta",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 24,
#   "pad_token_id": 1,
#   "type_vocab_size": 1,
#   "vocab_size": 50265
# }

# %% [markdown]
# ### Manual examples

# %%
pred = ses.predict(
    "I like sports",  # premise 
    "I like soccer",  # hypothesis 
)

pred
# Out:
# (tensor(1), tensor([1.3612e-03, 9.9769e-01, 9.4710e-04]))

# %%
pred = ses.predict(
    "I like soccer",  # premise 
    "I like sports",  # hypothesis 
)

pred
# Out:
# (tensor(2), tensor([0.0016, 0.3138, 0.6846]))

# %%
pred = ses.predict(
    "I like apple",  # premise 
    "I like apple and banana",  # hypothesis 
)

pred

# %%
pred = ses.predict(
    "I like apple and banana",  # premise 
    "I like apple",  # hypothesis 
)

pred

# %% [markdown]
# ### Load AMASum

# %%
dataset_dir = "/Users/ytshao/Desktop/Yutong/dataset/AMASum/form_min_10_max_100_revs"
split = "valid"
dataset_path = os.path.join(dataset_dir, f"{split}.source")
target_path = os.path.join(dataset_dir, f"{split}.target")

# %%
# List[<product>:List[<doc>:List[<sent>:str]]]
products = []

with open(dataset_path, 'r') as f:
    for l in tqdm(f):
        product_docs = l.strip().split('</s>')
        product_docs_sents = []
        for doc in product_docs:
            sents = sent_tokenize(doc)
            sents = [sent for sent in sents if len(sent) > 3]
            product_docs_sents.append(sents)
        products.append(product_docs_sents)
# Out:
# 0it [00:00, ?it/s]

# %%
# List[<product>:List[<summs>:List[verd, pros, cons]]]
product_summs = []

with open(target_path, 'r') as f:
    for l in tqdm(f):
        summs = l.strip().split('</s>')
        product_summs.append(summs)
# Out:
# 0it [00:00, ?it/s]

# %%
n_products = len(products)
n_docs = sum([len(product) for product in products])
n_sents = sum([sum([len(doc) for doc in product]) for product in products])
n_products, n_docs, n_sents
# Out:
# (3302, 256764, 1086461)

# %%
len(product_summs)
# Out:
# 3302

# %%
short_sent_counter = Counter()

for product in products:
    for doc in product:
        for sent in doc:
            if len(sent) <= 10:
                short_sent_counter[len(sent)] += 1

sorted(short_sent_counter.most_common())
# Out:
# [(4, 1243), (5, 1564), (6, 1431), (7, 1847), (8, 2628), (9, 3063), (10, 4958)]

# %% [markdown]
# ### Check: review sentences vs. gold summ
# Too slow to predict for all

# %%
entail_counter = Counter()

pbar = tqdm(total=n_sents)
for product, summ in zip(products, product_summs):
    for doc in product:
        for sent in doc:
            pred, probs = ses.predict(sent, summ)
            pred = pred.item()
            if pred == 1:
                res_str = 'neutral'
            elif pred == 0:
                res_str = f'contra-{probs[0].item():.2f}'
            elif pred == 2:
                res_str = f'entail-{probs[2].item():.2f}'
            entail_counter[res_str] += 1
            
            pbar.update(1)
            
pbar.close()

# %%
sorted(entail_counter.most_common())
# Out:
# [('contra-0.37', 1),
#  ('contra-0.38', 4),
#  ('contra-0.40', 2),
#  ('contra-0.41', 5),
#  ('contra-0.42', 9),
#  ('contra-0.43', 5),
#  ('contra-0.44', 7),
#  ('contra-0.45', 13),
#  ('contra-0.46', 21),
#  ('contra-0.47', 29),
#  ('contra-0.48', 48),
#  ('contra-0.49', 41),
#  ('contra-0.50', 60),
#  ('contra-0.51', 72),
#  ('contra-0.52', 76),
#  ('contra-0.53', 56),
#  ('contra-0.54', 72),
#  ('contra-0.55', 56),
#  ('contra-0.56', 47),
#  ('contra-0.57', 58),
#  ('contra-0.58', 58),
#  ('contra-0.59', 48),
#  ('contra-0.60', 72),
#  ('contra-0.61', 49),
#  ('contra-0.62', 48),
#  ('contra-0.63', 43),
#  ('contra-0.64', 34),
#  ('contra-0.65', 51),
#  ('contra-0.66', 50),
#  ('contra-0.67', 33),
#  ('contra-0.68', 35),
#  ('contra-0.69', 33),
#  ('contra-0.70', 30),
#  ('contra-0.71', 36),
#  ('contra-0.72', 38),
#  ('contra-0.73', 35),
#  ('contra-0.74', 30),
#  ('contra-0.75', 40),
#  ('contra-0.76', 27),
#  ('contra-0.77', 28),
#  ('contra-0.78', 26),
#  ('contra-0.79', 34),
#  ('contra-0.80', 33),
#  ('contra-0.81', 38),
#  ('contra-0.82', 25),
#  ('contra-0.83', 34),
#  ('contra-0.84', 32),
#  ('contra-0.85', 47),
#  ('contra-0.86', 39),
#  ('contra-0.87', 45),
#  ('contra-0.88', 37),
#  ('contra-0.89', 37),
#  ('contra-0.90', 30),
#  ('contra-0.91', 35),
#  ('contra-0.92', 39),
#  ('contra-0.93', 33),
#  ('contra-0.94', 29),
#  ('contra-0.95', 29),
#  ('contra-0.96', 27),
#  ('contra-0.97', 28),
#  ('contra-0.98', 12),
#  ('contra-0.99', 3),
#  ('entail-0.37', 1),
#  ('entail-0.39', 1),
#  ('entail-0.43', 3),
#  ('entail-0.44', 1),
#  ('entail-0.46', 3),
#  ('entail-0.47', 4),
#  ('entail-0.48', 7),
#  ('entail-0.49', 7),
#  ('entail-0.50', 17),
#  ('entail-0.51', 8),
#  ('entail-0.52', 8),
#  ('entail-0.53', 7),
#  ('entail-0.54', 9),
#  ('entail-0.55', 8),
#  ('entail-0.56', 5),
#  ('entail-0.57', 4),
#  ('entail-0.58', 4),
#  ('entail-0.59', 11),
#  ('entail-0.60', 10),
#  ('entail-0.61', 3),
#  ('entail-0.62', 4),
#  ('entail-0.63', 3),
#  ('entail-0.64', 6),
#  ('entail-0.65', 4),
#  ('entail-0.66', 4),
#  ('entail-0.67', 2),
#  ('entail-0.68', 3),
#  ('entail-0.69', 7),
#  ('entail-0.70', 1),
#  ('entail-0.72', 3),
#  ('entail-0.73', 4),
#  ('entail-0.74', 3),
#  ('entail-0.75', 1),
#  ('entail-0.78', 2),
#  ('entail-0.79', 1),
#  ('entail-0.80', 1),
#  ('neutral', 9795)]

# %% [markdown]
# #### Entail / contra pairs

# %%
entail_pairs = []
contra_pairs = []

pbar = tqdm(total=n_products)
for product, summs in zip(products, product_summs):
    summ = summs[0]  ## verd 
    for doc in product[:1]:
        for sent in doc[:1]:
            pred, probs = ses.predict(sent, summ)
            pred = pred.item()
            if pred == 0:
                contra_pairs.append((sent, summ, f'contra-{probs[0].item():.2f}'))
            elif pred == 2:
                entail_pairs.append((sent, summ, f'entail-{probs[2].item():.2f}'))
            
            pbar.update(1)
            
pbar.close()
# Out:
#   0%|          | 0/3302 [00:00<?, ?it/s]

# %%
entail_pairs
# Out:
# [('i recommend this, it\'s perfect for the our box garden, "eases bending over back pain" easy to scoot left and right while sitting and working harvest,',
#   "A unique cart won't work for everyone, but provides both a portable garden tool compartment and handy seat for those who can use it. ",
#   'entail-0.75'),
#  ('I love this case for my new Mac book 12 inch, it fits perfectly, and protects my laptop.',
#   'Highly protective and well padded, this case will keep your laptop safe in a fall. ',
#   'entail-0.53'),
#  ('Follow-up: This is a very nice piece except for the hardware.',
#   'Stands out for its solid construction. This is a great option once you get past the “heavy fumes” period. ',
#   'entail-0.56'),
#  ('My son loves these PowerBar Protein Bars.',
#   'For those looking to augment lean muscle growth, this is a tasty protein bomb. ',
#   'entail-0.61'),
#  ('I definitely recommend these.',
#   'Worth considering for pet owners who need a digestive supplement with appealing flavor. If side effects occur, they are likely to ease up in most pets when taken on a regular basis. ',
#   'entail-0.59'),
#  ("We've only used Gravol 3 or 4 times, but we've had no carsickness on those times.",
#   'This fruit-flavored liquid is easier to get into some children than a pill. ',
#   'entail-0.53'),
#  ('So I was having horrible luck with horse cross ties bought these for it because they could break everything else.',
#   'A heavy-duty dock line meant for a variety of uses on the water and around the dock. ',
#   'entail-0.77'),
#  ("I'm fairly new to rock climbing, so this is the first belay device I have owned.",
#   'A simple belay device that can be used with all sorts of ropes and for all different activities. ',
#   'entail-0.56'),
#  ('I was hesitant due to some of the negative comments stating they had received a used item.',
#   'Has a higher clearance than other cutters, so it can be used to cut thicker materials. Its cutting surface is not as wide, though, so consider what you want to make. ',
#   'entail-0.75'),
#  ('I really like this sandal but must warn - You must break them in!!',
#   "Sensible shoes that don't look sensible. Still, not as much arch support as other Vionic styles. ",
#   'entail-0.45'),
#  ('I had been using my 9X9 easy press to make earrings, but the Mini has been a game changer!',
#   "Pint-sized powerhouse that's perfect for customizing small and awkwardly-angled projects. ",
#   'entail-0.53'),
#  ("With 100 blades good for 3-4 shaves and it's like $4 for another 100 kits like this you'll never need another razor for YEARS.",
#   'If you can deal with a straight razor, this is a great choice for those wanting the closest shave possible. ',
#   'entail-0.57'),
#  ('It’s a great product but save your money and buy the TRX to go.',
#   'Durable components in a suspension training kit that should give you a good value over time. ',
#   'entail-0.83'),
#  ('I purchased a Westinghouse 7871400 Contrempra fan.',
#   'A simple choice for adding a light to your ceiling fan. Three-light design limits the amount of bulbs required, saving time and energy when it comes time to install. ',
#   'entail-0.52'),
#  ("This is a great light for kids because it's bright and doesn't get hot.",
#   'A versatile lamp that provides plenty of light. ',
#   'entail-0.89'),
#  ('I first bought the Lifewit Cotton Canvas storage bags with the metal frame.',
#   'Thick cotton canvas construction allows it to be tough and withstand some damage, while maintaining breathability. ',
#   'entail-0.80'),
#  ('Absolutely great!',
#   'An affordable organizer with enough room for everyday essentials. Ideal for personal front seat items or as a compact backseat organizer in vehicles with limited legroom. ',
#   'entail-0.60'),
#  ("Can't say enough good about this easel, my daughter loves to draw, I have twins, they have had this done they were 2, they will be 7 in October and it is still working great, nothing has ever broken on it, sturdy, well made and there is a tray in between that holds alot, my daughter puts her work books there.",
#   'With dual sides, a tray for art supplies, and a sturdy frame, this kids’ easel delivers great value for money. A good option for budding artists. ',
#   'entail-0.70'),
#  ('I bought this for my 59 year old hubby for his birthday.',
#   "If you are an advanced pogo stick user looking for major jumping ability, this is the one to get. Otherwise, it's likely to be too difficult to operate for the average user. ",
#   'entail-0.65'),
#  ('I bought this in hopes that my 23lb, 7 year old cat would lose some much needed weight.',
#   'High-fiber option will help keep your cat full for extended periods, preventing overeating. ',
#   'entail-0.50'),
#  ('Great knee board!',
#   'Good size and design of board allows it to work well for kids and adults alike. ',
#   'entail-0.50'),
#  ('2nd time wearing this.',
#   'Roomy design made for those with long hair, braids, or dreadlocks. Popular for those with curly or thick hair as well. ',
#   'entail-0.51'),
#  ('These bottle are INCREDIBLE.',
#   'A basic travel bottle to keep your toiletry liquids safe while moving around at the airport. Good choice to keep a number of different liquids protected. ',
#   'entail-0.57'),
#  ('I do collision repair for a living and this is a must need tool.',
#   'A must-have for body work or other metal sanding, or for getting into hard-to-reach spots. ',
#   'entail-0.71'),
#  ('Outstanding performance.',
#   'The laser-based Matter and Form 3D Scanner is a good companion for a 3D printer. ',
#   'entail-0.67'),
#  ("not sure if it's me or if it's the recorder, but the volume is not nearly as loud as my old olympus that I paid 35.00 for a couple of years at Costco.",
#   'A mid-level voice recorder that comes with a combination of some convenient features and a few design flaws. ',
#   'entail-0.63'),
#  ('Absolutey love these sneakers!',
#   'A moderately supportive, relatively lightweight running shoe. ',
#   'entail-0.96'),
#  ('After years of stirring drinks in tall glasses with regular tea spoons I decide to look on Amazon for tall spoons.',
#   'Spoons have an expensive look and feel to them at an inexpensive price point. ',
#   'entail-0.42'),
#  ('This is a great projector, the colors are vibrant and picture very sharp.',
#   'Bright projector provides a full HD ratio video signal. Software generates great color results. ',
#   'entail-0.55'),
#  ('Great piece for the price!',
#   'For an exposed-bulb, industrial look, this is an affordable choice that looks great. ',
#   'entail-0.87'),
#  ('Great calculator.',
#   'This is the ultimate tool for people in engineering and computer science fields. An overall amazing calculator. ',
#   'entail-0.52'),
#  ('I purchased this food processor because it was a kitchenaid and the color matched my decor.',
#   "Though compact, it's highly capable of various kitchen tasks. Great for consumers who don't have space for a larger processor. ",
#   'entail-0.56'),
#  ("This skillet is everything I've come to expect with Farberware.",
#   "A timeless pan from a longstanding manufacturer of respected kitchenware. You can't go wrong with this dependable piece. ",
#   'entail-0.85'),
#  ('This is the second I have owned.',
#   'The Rolls Royce of weather stations, this expensive device rivals most pro-grade units. ',
#   'entail-0.60'),
#  ('The helmet itself is great.',
#   'Well-padded helmet that provides the necessary protection without affecting sight lines. ',
#   'entail-0.53'),
#  ('This works.',
#   'Clear plumper designed to be used under your lip color. The “next best thing” to injections. ',
#   'entail-0.53'),
#  ('We bought these for a trip to DisneyWorld.',
#   'The unusual material of these cooling cloths stay cool and wet, but dry to the touch. ',
#   'entail-0.46'),
#  ("Best reasonably priced foundation I've tried.",
#   'Lightweight formula diminishes the look of fine lines and wrinkles, leaving a good canvas for foundation. ',
#   'entail-0.60'),
#  ('This portable air conditioner fan has a basic mechanism - it has a fan and some type of radiator inside of it.',
#   'A compact evaporative cooling fan that is small enough to fit on your desk or nightstand. ',
#   'entail-0.53'),
#  ('I love these maternity jeans and wish I would have ordered sooner.',
#   'These jeans are attractive and comfortable at an affordable price, yet not the top value. ',
#   'entail-0.52'),
#  ('Nice reel for the price.',
#   'A quality reel for a decent price. ',
#   'entail-0.96'),
#  ('I purchased two of these-one for my daughter’s new Toyota Corolla SE (blue trim) and one for my 2016 Volvo XC90 Inscription (black trim).',
#   'This model provides the look, quality, and feel of a genuine leather product. ',
#   'entail-0.38'),
#  ('Best mixer ever!!',
#   'Efficiency and easy power controls makes for simple  cooking with exceptional results. ',
#   'entail-0.51'),
#  ('Real disappointed in my Mixpresso Single serve coffee maker.',
#   'Reliable brewer with a nice design that can fit most cup sizes. Comes equipped with a variety of convenient features. ',
#   'entail-0.48'),
#  ('This would be lovely if it worked.',
#   'Worth a look if you want an option for just a few people, but it comes with the possibility of a few issues. ',
#   'entail-0.51'),
#  ('He loves it...however...the bug went to somewhere under the oven, and disappeared... My cat has been like this for two days...',
#   'A fun and engaging toy with bug-like realness. ',
#   'entail-0.80'),
#  ('I wear 13 wide, and cannot find bike shoes in my size, (maybe they are trying to tell me something).',
#   'A step up from most budget-level cycling shoes. Offers more performance and aerodynamics. ',
#   'entail-0.66'),
#  ('Love this wagon.',
#   'This collapsible cart offers plenty of space and is easy to store. ',
#   'entail-0.51'),
#  ('Okay...',
#   'This lamp offers a stylish choice at an affordable price tag. With its dimmable control and attractive stand, it adds ambiance and warmth to any room. ',
#   'entail-0.47'),
#  ('I bought this because the all plastic versions last maybe two days, so I was stoked to see this was metal.',
#   'The goalposts in this set consist of a powder-coated steel that will last over time. ',
#   'entail-0.54'),
#  ('Great quality and stores perfectly within my kayak storage area behind the seat.',
#   'Works well with small vessels like kayaks, canoes, paddleboards. ',
#   'entail-0.83'),
#  ('These are the real Deal..!!',
#   'A modern matte style that looks stealthy yet functions for more than a metropolitan look. ',
#   'entail-0.46'),
#  ("So far, this is the best non-track-saw circular saw that I've used.",
#   'A fairly light circular saw that offers enough power for most DIY jobs along with desired safety features like a guard and brake. ',
#   'entail-0.54'),
#  ('Get a Sawyer-Mini.',
#   'This exceedingly popular water filter is a remarkable choice for those wanting a supreme filtration system with a simple design. ',
#   'entail-0.52'),
#  ('Nice and cheap and works well for basic soldering needs.',
#   'Basic, no-frills soldering iron. So cheap it could be seen as disposable. ',
#   'entail-0.63'),
#  ('One star because package was delivered fast.. my iron appeared to have been used there was water droplets in the iron reservoir, the iron did not work or turn on.',
#   'A powerful yet lightweight option that offers the choice of using steam or ironing dry. ',
#   'entail-0.66'),
#  ('I have done some simple testing of PM 2.5 with visibility and other PM measurements.',
#   'A good handheld air quality monitoring option for more detailed and accurate results. ',
#   'entail-0.57'),
#  ('I love this sofa!',
#   'Features a contemporary design that looks modern, but still classic. A truly functional focus piece for any front room. ',
#   'entail-0.56'),
#  ('One of my favorite kitchen gadgets!',
#   'Indeed a fun cupcake maker that bakes 6 cupcakes in 3 steps: use your best-loved box or scratch recipe, bake and cook. ',
#   'entail-0.51'),
#  ('This guide is full of different species of insects, arachnids, and arthropods.',
#   'A book that covers a wide variety of spiders and insects. ',
#   'entail-0.94'),
#  ('My kids love, love, love this set.',
#   'Tetherball system with a sturdy base that allows you to move the equipment where you want. ',
#   'entail-0.52'),
#  ('It was a good guitar while it lasted.',
#   'An adequate starter pack for beginners, but not an instrument meant to last an entire musical career. ',
#   'entail-0.65'),
#  ("It's the perfect GoPro for beginners.",
#   'Meant as a "starter" camera, this is robust enough to stick with you until you decide you need something more advanced. ',
#   'entail-0.52'),
#  ("Let me start by saying I'm in love with these chairs.",
#   'Classic looks with a great amount of comfort and padding. ',
#   'entail-0.52'),
#  ("I bought these for a wine party that I recently had and the ladies would be writing their names on their glasses so they each would know who's glass belong to whom.",
#   'High-quality markers and charms allow for truly personal wine glasses. ',
#   'entail-0.55'),
#  ('I have learned a lot about cargo bags since about a week ago.',
#   'Huge storage capabilities and waterproof material make this a convenient option. ',
#   'entail-0.62'),
#  ('Really great kayak, big enough easily for me and my dog.',
#   'Reasonable price point for a basic kayak. Adequate room for larger adults. ',
#   'entail-0.66'),
#  ("I think I'll by from Clinique direct.",
#   'A cleanser that gives a really clean feel, without the harsh stripping quality of regular soaps. ',
#   'entail-0.56'),
#  ('I bought three, installed them on pontoon boat.',
#   'A basic seat with decent padding and arm rests. ',
#   'entail-0.51'),
#  ("It's a nice size for a small desktop gong, hitting it feels satisfying, and it makes a decent sound (though of course it can be better).",
#   'This hand-hammered gong comes on its own stand and is compact enough to sit on the corner of your desk, on a coffee table, or a countertop. ',
#   'entail-0.45'),
#  ('Super cute, super comfy.',
#   'A well-constructed, comfortable shoe for all day wear. A good choice if your occupation keeps you on your feet. ',
#   'entail-0.58'),
#  ('These are great feeling golf shoes.',
#   'Progressive is the theme of the Adidas CodeChaos BOA, and it reflects on both of its style and features. The shoe easily stands out on the course. The high-top built combined with the BOA lacing system are the features that excelled for golfers. Besides that, necessary qualities like comfort, stability, and grip remain to be present for this version. ',
#   'entail-0.51'),
#  ('If you are keeping reptiles, especially diurnal, this device is a must have.',
#   'Integral product to maintain reptilian environments. ',
#   'entail-0.87'),
#  ('I had a pair of New Balance Fresh Foam shoes I bought several years ago which I loved and wore until there were holes in the bottom.',
#   'A lightweight neutral shoe built for fast efforts on the road. ',
#   'entail-0.53'),
#  ("It doesn't really grate as much as it shaves tiny pieces.",
#   'This durable rotary grater showcases a sleek design alongside durable construction. ',
#   'entail-0.56'),
#  ('You know a product\'s reviews are fake or incentivized when you have people leaving 5-stars proclaiming they\'re of "amazing quality!"',
#   "A nice assortment that's fun for dogs who love to chew and play. They are reasonably sturdy, but they are not indestructible. ",
#   'entail-0.42'),
#  ("I'm using it to cover my winter wheels, which are stacked outside my shed.",
#   'A practical, versatile option for protecting more than one tire when not in use, such as a set that you need to store during off season. ',
#   'entail-0.90')]

# %%
contra_pairs
# Out:
# [("Buyer beware: while the ad doesn't say it this is a costco warehouse version of the tommy Bahamas chair, so cheaper quality.",
#   "If you are looking for the ultimate beach chair, this one has numerous features its competitors can't top — nearly everything you need in a chair specifically designed for the beach. ",
#   'contra-0.68'),
#  ('I purchased these to replace what should have been identical Riedel glasses that we broke.',
#   'An affordable version of one of the most popular bowl shapes from the pricier Vinum range. ',
#   'contra-0.56'),
#  ('The programme removed viruses from my computer exactly as promised.',
#   "If a malware infestation keeps you from booting Windows or running an antivirus scan, the bootable FixMeStick can save you. But don't ditch your existing antivirus; FixMeStick offers no real-time protection. ",
#   'contra-0.96'),
#  ('I purchased these less than two months ago and the black exterior coating started to peel off all of them last week.',
#   'Stainless steel construction and available in 3 color choices, this cup is durable and perfect for camping. ',
#   'contra-0.96'),
#  ("We loved this ball for the first 6 months, but now it has a tiny hole in it and won't hold air.",
#   'Solidly built, classic red kickball that will last a long time.  The seamless ball design holds air better. ',
#   'contra-0.95'),
#  ('As others have said, it fits loosely into the hitch.',
#   'A heavy-duty steel hitch step that will last you for many years without rusting or falling apart. ',
#   'contra-0.99'),
#  ('The somewhat low rating is merely because of the instructions.',
#   'A basic choice for anyone wanting to add some functional lighting to their ceiling fan. Goes well with a number of design styles. ',
#   'contra-0.90'),
#  ("This was my first major appliance I've purchased online so I was a bit hesitant-there was no need!",
#   'Ideal for budget-conscious consumers looking for a smaller microwave, but it tends to be noisy. ',
#   'contra-0.60'),
#  ('Fast standard shipping!',
#   'Dissipates impact energy efficiently. Provides maximum comfort when wearing it for a full day. ',
#   'contra-0.78'),
#  ("They fit perfect I bought it on January 9th I don't wear it all day or everyday only like (10hrs )2 or 3 day week and this is what happened so far .",
#   'Like the original Keen Austin, this mid-top version has gained acclaim from reviewers due to its water-resistant properties and versatility. Wearers attested to its comfort and support, even to those who have sustained various foot-related issues.\xa0The Keen Austin Casual Waterproof Cleat delivers all the essentials, whether used casually or while working. However, its laces are a different story as many have complained about its qualities. ',
#   'contra-0.52'),
#  ('I bought this set of cups, to serve a good coffee in my days of camping, I am disappointed with the product because once you serve the coffee in the cup, it takes a very unpleasant metal taste, I had to discard them for garbage , this set of cups are very nice but I do not recommend it',
#   'The ideal pick for buyers wanting a travel mug specifically designed for coffee and tea. ',
#   'contra-0.95'),
#  ('Not responsive.',
#   'A voice-controlled smart speaker that fits a lot into its compact design. Exceptionally great value for the money considering what it can do. ',
#   'contra-0.55'),
#  ('I have baby fine, chest length hair that tangles in a light breeze.',
#   'The type of scalp shampoo brush to choose when you want a simple massage. ',
#   'contra-0.68'),
#  ('Yes, these seem to have all the features necessary for their intended purposes; except ONE.',
#   'Abrasion-resistant fabric and dual closures over thigh and back of knee mean all-day comfort from these cushion-and-foam knee pads. ',
#   'contra-0.64'),
#  ("Its inner parts is made of soft plastic, it can't last longer, it is broken in 1 and half year.",
#   "A well-built faucet that feels solid and looks attractive. Works well and won't disappoint. ",
#   'contra-1.00'),
#  ("I wanted to wait before I wrote my review...i bought these in September so here goes....dont waste another dime on anything but stainless steel....i always bake with parchment paper and the parts that weren't covered turned dark brown, you can't get it off!",
#   'These nonstick sheets clean up easily and nest together to save cabinet space. ',
#   'contra-0.92'),
#  ('Currently a one star review.',
#   "Sony's DualShock 2 Analog Controller stands as the best of its generation and the blueprint for almost every controller released since. ",
#   'contra-0.97'),
#  ("This poor rating is reflective of Conair's return policy and not Amazon.",
#   'This compact, folding hair dryer is perfect for travel, yet it works well as a full-size dryer. ',
#   'contra-0.90'),
#  ('Seems to be high quality, and I’m sure a bargain for most projectors out there but didn’t fit my Epson.',
#   'A sturdy little projector mount and a good value for the money. ',
#   'contra-0.50'),
#  ('So I say that these fit somewhat small, as from other reviews, I ordered up a half size.',
#   'The Adidas Pure Boost ZG brings comfort, flexibility and durable support to the runner. Each step becomes natural because of its soft coverage, the responsive mid-sole system, and the layered EVA outsole. Neutral runners are going to have a great time with this Adidas running shoe. ',
#   'contra-0.66'),
#  ('Sorry to say this is really a waste of money.',
#   "Amazing price, compatibility, and customer support. As long as you don't have your heart set on a multi-color bulb, you won't find a smart bulb that offers more. ",
#   'contra-0.98'),
#  ('The app that accompanies this product is simply garbage.',
#   'Top-notch technology with a few "bugs" – choose if you want a mini smart plug and don\'t mind the higher price. ',
#   'contra-0.99'),
#  ('I loved the feel of and balance of this, but as you can see, it was not of the best quality.',
#   "This small axe has a great design and an affordable price. It's an appealing deal for the budget-conscious. ",
#   'contra-0.97'),
#  ('Well made single-speed beach cruiser - arrived in perfect condition, easy to put together, excellent finish.',
#   "A basic model with mid-level speed that's attractive and easy to ride – but it isn't the most reliable or comfortable one we considered. ",
#   'contra-0.45'),
#  ('Fantastic phone.',
#   "The ultra-tiny Unihertz Jelly Pro is a fun novelty device, but it can't in any way compete with full-size phones. ",
#   'contra-0.98'),
#  ('The rabbit had a terrible and cruel welcome into this world.',
#   'These super-fuzzy and soft wildlife toys are an excellent consolation prize if your dog is still fuming over the squirrel they’ll never catch. ',
#   'contra-0.88'),
#  ('Great Camera, being a professional photographer, sometime I am not able to bring my professional DSLR with me but this camera fill in the gaps on that.',
#   'Sluggish performance and a more limited feature set than similarly priced competitors hold the Canon PowerShot G5 back from being a leading contender among its peers. ',
#   'contra-0.98'),
#  ('Imagine the guts of an iPhone 11 smashed into the chassis of your favorite iPhone 5; if that sounds appealing, then this is the phone for you.',
#   "Slim, sleek, and light, it's a contemporary iPhone that gives you the basics at an affordable price. ",
#   'contra-0.76'),
#  ('It was amazing, We used it to bring a large wooden Wishing Well up some stairs and it rolled up the stairs without damaging the edges of the stairs.',
#   'This cart, with a 330 pound maximum weight limit, "walks" over steps thanks to its three-wheel construction. ',
#   'contra-0.62'),
#  ('This shampoo does not lather well.',
#   'This shampoo will leave even the thickest hair silky smooth. ',
#   'contra-0.96'),
#  ('Had an absolute nightmare trying to get this to work, the website offers Windows 10 drivers but these do not work.',
#   'The Brother QL-800 prints several sizes of high-quality label types from your PC, Mac, or Android mobile device via USB, making it an excellent value for its relatively low price. ',
#   'contra-0.96'),
#  ('This is not a high quality product at all.',
#   'This extra set of eyes boasts easy installation and a smooth wireless signal. ',
#   'contra-1.00'),
#  ('Battery not included 😕 missed that.',
#   "A basic cordless leaf blower that takes a battery that's compatible with other WORX Power Share tools. ",
#   'contra-0.91'),
#  ("Most painful shoes I've ever tried wearing.",
#   "A comfortable and durable sport sandal that's easy to slip on and off. ",
#   'contra-1.00'),
#  ('I liked that this product was affordable.',
#   'This large kit includes alphabet and number tiles, cars, light-up tiles, geometric shape tiles, and just about anything else you could imagine. ',
#   'contra-0.65'),
#  ('My cat has had wore his tick collar for about 2 weeks and received chemical burn..',
#   "This thin, comfortable collar can be worn with your cat's standard collar and is reflective for nighttime safety. ",
#   'contra-0.50'),
#  ('This product does NOT come with the a/c adapter to power it on but do not see that it says it anywhere when purchasing this product.',
#   'An inexpensive package that gives you 20 classic PlayStation titles. Simple plug and play design. ',
#   'contra-0.65'),
#  ("Is great product although very limited, can't install or add programs due to softwarw restrictions",
#   'The Dell XPS 10 Windows RT-equipped convertible tablet will truly last all day and most of the night (and certainly cover the longest flight in the world). It has a very small-capacity C: drive, but if your digital life is truly in the cloud, the XPS 10 can totally be the everyday computer that you carry everywhere. ',
#   'contra-0.84'),
#  ('Purchased this lovely item toward the end of winter.',
#   'Gently glides and trains dogs into heel position, providing barrier between dog and bike. ',
#   'contra-0.54'),
#  ("These pillows aren't terrible, but they are definitely not as comfortable as I thought they would be.",
#   "With this pair's gel-infused fiber, comfort that most users brag about, and budget-friendly price, you won't find a better deal in this class. ",
#   'contra-0.93'),
#  ('I’m honestly disappointed at the quality of the blocks as well as the reconstruction support.',
#   'This is the latest version of the classic Jenga set from Hasbro. Simple game rules make Jenga an appealing choice for players of all ages, and the size is perfect for coffee, kitchen, or gaming tables. ',
#   'contra-0.76'),
#  ('I used the small K&H Manufacturing Lectro-Soft Outdoor Heated Bed in a home-made outdoor cat shelter all of last winter.',
#   'This functional dog bed is excellent for those looking to keep their dog warm in chilly weather. ',
#   'contra-0.43'),
#  ('Purchased New, received Used, already registered to another owner, with a game disc in the tray.',
#   "The PlayStation Pro's upgraded internals deliver stunning 4K HDR gaming. Perfect for hardcore gamers who want to enjoy every last pixel. ",
#   'contra-0.93'),
#  ('Product was not properly sealed.',
#   'This is an impressive massage oil for anyone with sensitive skin, with a desirable consistency and scent as well. ',
#   'contra-0.83'),
#  ('There is a "standard" keyboard design for a reason.',
#   'With a beautiful design, excellent performance and battery life and a great display, the Lenovo Yoga 910 is one head-turning hybrid. ',
#   'contra-0.72'),
#  ('Modifying my initial review - Originally, two of the candles did not work out of the box and I had started the return process.',
#   'These life-like flameless candles come in a set of 6, making it easy to spread them out or use in different rooms. ',
#   'contra-0.92'),
#  ('One star for bad client-centred approach.',
#   'A heavy-duty waffle maker with smart features that make cooking waffles to the perfect doneness easy. ',
#   'contra-0.98'),
#  ('I do not like it.',
#   'Ideal for smaller workspaces, this scroll saw cuts accurately with a bit of practice. ',
#   'contra-0.90'),
#  ('Seems brighter than a 60 watt incandescent, which is what i was looking for.',
#   'This simple, low-cost LED is a strong performer with plenty of upfront value. ',
#   'contra-0.48'),
#  ('I don’t understand why there are bad reviews.',
#   "This bike won't work for everyone, but it's great for couples or a pair of friends who want to cruise along the coastline together. ",
#   'contra-0.69'),
#  ('The pen is very hard to use and is very frustrating.',
#   "While it's an older model, performance is solid and it has many of the premium perks seen in the 2020 design. ",
#   'contra-0.98'),
#  ('I purchased 3 of these and each one was slightly different.',
#   'One of the all-around best pool noodles you can buy in terms of durability and weight support. ',
#   'contra-0.74'),
#  ('This is not a real you want to buy.',
#   'A lightweight saltwater reel made of quality materials that last a long time. ',
#   'contra-0.72'),
#  ("I took apart the glove and it's thin plastic in the knuckle pads.",
#   'An affordable pair of fully armored gloves meant for motorsports and other extreme activities. ',
#   'contra-0.97'),
#  ('Product is unusable.',
#   'A supportive mattress for larger sleepers that is firm enough to help relieve back pain. ',
#   'contra-0.56'),
#  ('Some sizes of RV tires have few manufacturers.',
#   'A slick, all-around trailer tire that provides a good balance of performance, durability, and value. ',
#   'contra-0.82'),
#  ('I signed my daughter up for her first swim class!',
#   "A thick and durable swim cap that is designed to keep all of your child's hair dry. ",
#   'contra-0.49'),
#  ('First, let me just say that we did not buy an "outdoor TV" for our deck.',
#   'The Panther Series cover is compatible with most flat panel sets, and works with wall mounts and stands. ',
#   'contra-0.48'),
#  ('This is the first booster set I have purchased for any card game ever.',
#   'Explore the gritty depths of Ravnica, where crafty players will find good use for the frog mutants, mighty angels, and deadly ogres that call it home. ',
#   'contra-0.83'),
#  ('I never write online reviews, but this product is a scam.',
#   'This good quality safe provides a lot of space and comes with a hearty fire and water rating. ',
#   'contra-1.00'),
#  ('The tarp is put together quite well however after further inspection the ridgeline stitching has visible micro pinholes from the stitching that did not get sealed entirely that through a good down poor or would allow a significant amount of moisture to pass through.',
#   'This rain fly hammock tent is the perfect choice for those who need to purchase a tarp without the hammock. ',
#   'contra-0.88'),
#  ('Horrible product and its quality.',
#   'An elegant design with a blue knit cover, these wide-mouth bottles retain heat well and are easy to use. ',
#   'contra-1.00'),
#  ('I previously owned a jasper mother board x-box, so since I already had games power supplies etc.',
#   'Now that Blu-ray has become the pre-eminent high-definition standard for discs, the Xbox 360 has yet to support it, but it still remains an excellent game console with a superior game library and online experience. ',
#   'contra-0.74'),
#  ('The juicer arrived very quickly in New Zealand - less than a week.',
#   'Avoid the complex and troublesome to clean Hurom H-AA Slow Juicer in favor of better performing models such as the Omega J8006. ',
#   'contra-0.86'),
#  ('Took me 15 years to find something to clear up the scaring I caused from picking in my face.',
#   'Botanical extracts and peptides foster new skin growth and tone its texture. ',
#   'contra-0.95'),
#  ("I just got this today and I'll update my review if this is just an issue where I got a defective screen but the color across this screen is very uneven.",
#   'This 43" model has a reasonable screen size and saves you money over larger sets. ',
#   'contra-0.71'),
#  ("I don't usually write reviews but after all the raves here I purchased this tool.",
#   'Never use a knife again to remove kernels from the cob, this is the fastest, safest way to remove kernels off a cob. ',
#   'contra-0.74'),
#  ('All those flavored chips are repulsive to me.',
#   "The original flavor of the Lay's Kettle Cooked chip provides a high quality crispy chip you may mistake for a gourmet brand. ",
#   'contra-0.97'),
#  ('The top and bottom of the belt are fraying and the internal material is coming through.',
#   'This top-notch belt features a slim design and may help prevent hernia recurrence. ',
#   'contra-0.93'),
#  ('When I bought these, I got them 1/2 size larger than I normally wear, and they were still too small.',
#   'Altra Paradigm 3.0 generated a mixed response from its users. While the neutral running shoe provided excellent comfort and higher flexibility, some people believed that it could certainly use an improvement in its overall look and design for better durability and a firmer hold. ',
#   'contra-0.61'),
#  ('I needed more room and space for my clothes.',
#   'An exceptionally popular clothing rack dedicated to a simple, high-quality construction. ',
#   'contra-0.95'),
#  ('Was tired of my big canon 40d and big lenses.',
#   'The Olympus E-P1 is an otherwise excellent enthusiast compact camera hampered by some performance problems and the lack of a viewfinder and built-in flash. ',
#   'contra-0.94'),
#  ('Had a healthy wood turtle, fed her this and she was dead two days later.',
#   'Nature Zone’s moist and soft musk melon flavored gel cubes are both palatable for tortoises, as well as a nutritionally balanced formula containing the essential vitamins, minerals, fiber, and easily digested proteins they need to thrive. ',
#   'contra-0.55'),
#  ('The plastic seems sub par to original diaper genie.',
#   'These are an inexpensive alternative to brand name diaper pail refill bags for several different pails, making them a great value. ',
#   'contra-0.57'),
#  ('This product that was sold to me is not an authentic Stila eyeliner.',
#   'If you prefer traditional eyeliners that are soft and easy to smudge for smoky looks, this one lives up to its name. ',
#   'contra-0.97'),
#  ('The phone never worked, I had to send it back & get refunded & the sellers were not very thrilled or kind with me.',
#   'Though it lacks some features found in its big phone rivals, the Nokia Lumia 1520 is a great buy for Windows Phone fans seeking a supersize smartphone with premium hardware. ',
#   'contra-0.91'),
#  ('Although the plastic cover, strap and ear buds gave out.',
#   'With its many features as well as its compatibility with audiobooks and subscription-based music, the SanDisk Sansa m200 series is an overall great value. ',
#   'contra-0.78'),
#  ("These are ok for the price probably, but I only really bought it for one size, and it dented in and became unusable on the first try while attempting to loosen an engine mount bracket that my socket couldn't get to, it was the last bolt I needed out - so the vehicle will be disabled until I get a better quality wrench.",
#   "A basic, large set with acceptable quality and a value price. The best choice if you're watching your budget. ",
#   'contra-0.76'),
#  ('I am using the coffee latte flavor and mixing it up with Almond Milk.',
#   'A clean whey isolate protein powder with no additives or artificial sweeteners. ',
#   'contra-1.00'),
#  ('Do not buy this product as Seagate does not honor the warranty.',
#   'The Game Drive Hub’s ability to easily store over 200 games and its convenient USB ports make it a must-have model for hardcore Xbox One owners. ',
#   'contra-0.99'),
#  ('Extremely disappointed!!',
#   "It's a good choice if you are looking for a beach chair that isn't too low to the ground, but if the weight-bearing issues concern you, check out others we reviewed. ",
#   'contra-0.54'),
#  ("Not sure why exactly however the end rubber pieces seem to slide onto the pump much easier and stay in place better than the store bought ones I've used in the past.",
#   "A pack of 12 genuine Intex replacement filters (Type A) for Intex's smaller above-ground pool pumps. ",
#   'contra-0.67'),
#  ('Very disappointed.',
#   "Amazon's popular choice for the Paella pan is stylish and durable. ",
#   'contra-0.60'),
#  ("My Motorola Droid RAZR MAXX HD had great battery life (up to 4 days of light use) when I purchased it which decreased rapidly over time to the point that even with moderate use the battery couldn't make it through the day.",
#   'The Verizon Wireless Motorola Droid Razr Maxx HD provides plenty of power and enough battery life to keep you going all day. ',
#   'contra-0.87'),
#  ('Doesn’t work after using it maybe 5 times.',
#   "A powerful workhorse that combines a sleek design with 20V of power and long battery life to deliver performance the competition can't beat. ",
#   'contra-0.99'),
#  ('I bought the Canon 90D primarily for wildlife photography for use with Canon 100-400mm EF L zoom lens.',
#   'The Canon EOS 90D offers a new sensor with significantly more resolution than its predecessor, but competing mirrorless cameras have an edge in autofocus performance. ',
#   'contra-0.67'),
#  ('I use these smoking pellets along with the A-maz\'n 12" smoker tube.',
#   "A variety pack of 6 flavors of reliable wood chips that don't require soaking. ",
#   'contra-0.83'),
#  ('I bought this to help me with my recovery after a double mastectomy.',
#   'A set of four pieces to create the ultimate relaxing position in bed. ',
#   'contra-0.54'),
#  ('I have a more expensive 0 bag I use when it is below 20 degrees however I needed a very quick ultralight solution that was not only cost effective but available to deliver within 2 days to my house.',
#   'A mummy-style sleeping bag that is lightweight and warm and comes with an industry-leading warranty. ',
#   'contra-0.61'),
#  ("My F150's original driver side mirror was stolen.",
#   "A custom towing mirror that lets you quickly change the mirror's face position any time you choose. ",
#   'contra-0.97'),
#  ('Sadly this is not a good strap.',
#   'A simple and functional way to carry your mat without having to mess with a bag. ',
#   'contra-0.96'),
#  ('I usually use my Pentax DSLR - great photos but it is too big and heavy to carry around all the time.',
#   'Feature junkies in search of a compact megazoom should get the Sony Cyber-shot DSC-HX9V. ',
#   'contra-0.53'),
#  ('Doesn’t work.',
#   'This five-port HDMI switcher with active auto switch capabilities proves that more is better. ',
#   'contra-0.99'),
#  ('IT ALMOST STARTED A FIRE IN MY OFFICE!!!',
#   'Inexpensive version of a classic lamp. ',
#   'contra-0.98'),
#  ('The candles I received were NOT as pictured.',
#   'Never get caught in the dark again with this six-pack of clear, long-lasting emergency liquid candles. ',
#   'contra-1.00'),
#  ('This product is not as advertised.',
#   'Inexpensive and small, these are good as general party or bowling party favors. ',
#   'contra-0.92'),
#  ('I was planning on giving this 5 stars, but after about a week of use the clip doesn’t close completely any more.',
#   'The Clip 3 puts the “portable” in “portable speaker” with its ultra-light design, but its great sound quality and rugged form make it an excellent choice for daily use. ',
#   'contra-0.78'),
#  ('Nice item my second pellet grill wanted a smaller one.',
#   'A full-featured grill and smoker that is solidly constructed and easy to keep clean. ',
#   'contra-0.99'),
#  ('Apparently it cannot handle the weight of normal sized books.',
#   'A solid value for the price, this bookshelf is sturdy yet portable. ',
#   'contra-0.70'),
#  ('Apparently it cannot handle the weight of normal sized books.',
#   'An affordable space-saving bookshelf that you can stack for double the storage capacity. ',
#   'contra-0.76'),
#  ('We bought the expert set with screw-in brass fittings on the mallet heads and mallets.',
#   'A cheap alternative to the Franklin Professional Set that features lighter mallets. ',
#   'contra-0.69'),
#  ('How hard is it to make a plate that is flat?',
#   'A rugged, solid built table that offers a spacious work surface once assembled. The best deal for the budget-minded. ',
#   'contra-0.71'),
#  ('While I do like the bag, it imtakes FOREVER to squeeze juice through it as the pulp gets clogged due to the fabric being super tightly woven!',
#   "Natural materials come together to construct a sturdy and efficient nut milk bag that you'll feel safe using. ",
#   'contra-0.93'),
#  ('DO NOT BUY.',
#   'The Samsung Chromebook Pro will make a believer out of many Chromebook skeptics by offering great value, features and performance for a budget-priced laptop. ',
#   'contra-0.89'),
#  ('Ok girls I was skeptical about ordering this mirror after seeing reviews that said it runs off prematurely or it only turns on if you’re really close to it .',
#   'One of the brightest, clearest, and most distortion-free mirrors available. ',
#   'contra-0.96'),
#  ("Wanted to love it but it's just not loud enough for my needs.",
#   "JBL's Clip+ takes an already well-designed, travel-friendly and affordable Bluetooth speaker and adds water resistance. ",
#   'contra-0.53'),
#  ("Latest update: this product doesn't work.",
#   'With its large catch cage and bug-attracting power that covers up to an acre, this is the top model in the Dynatrap family. ',
#   'contra-0.54'),
#  ("It doesn't do a great job.",
#   'A top contender in robotic cleaners at a good price point. ',
#   'contra-0.54'),
#  ('If you have a 2080ti and are in the market for a 4k monitor this monitor is absolutely gorgeous.',
#   'This compact monitor boasts an impressive 1 millisecond response time and full HD resolution, making it a good gaming monitor for users who need a unit that will fit in a small space. ',
#   'contra-0.45'),
#  ("Keyboard costs $39, and it can't be used right out of the box.",
#   'Finger-sized keys and tons of instrument voices make this miniature keyboard a winner for young kids. ',
#   'contra-0.91'),
#  ('Assembly and installation of this fan was easy compared to the disaster I had with the Hampton Bay fan I bought at Home Depot, and returned.',
#   'A nice ceiling fan from a reliable brand that looks great and is easy to install. ',
#   'contra-0.76'),
#  ("I have not had issues with the operation of the machine, but they failed to include a component (mulching insert) in the box, and I can't get anyone to call me back at their (supposed) Customer Service Department.",
#   "Top-notch engineering, precision cutting, and rugged construction. Mower's modern tech is backed by a longstanding, respected company. ",
#   'contra-0.95'),
#  ('Outstanding Purchase .',
#   'A space-saving heavy freestanding bag with a narrow profile that fits almost anywhere inside. ',
#   'contra-0.55'),
#  ('These only slow my 2 year down by about 3 seconds.',
#   'Clear plugs that do not detract from your decor. ',
#   'contra-0.93'),
#  ('I contacted the seller first, explained they leaked asked for refund or replacement, they never responded.',
#   'Flexible beads, good fit for most customers, and two masks for the price make this duo your best choice if you are looking for a great deal. ',
#   'contra-0.93'),
#  ('Purchased this Stroller for my toddler and new baby and while using it it COLLAPSED!!',
#   'A deluxe, sturdy model that combines maneuverability, versatility, and quality – by far the best Baby Jogger on the market today. ',
#   'contra-0.92'),
#  ('This thing is garbage and the customer service is HORRIBLE.',
#   'Top-of-the-line model featuring plenty of bells and whistles for any cook looking to expand beyond the set-it-and-forget-it meal. ',
#   'contra-1.00'),
#  ('After reading oodles of negative reviews about all different mattresses on several different sites, I was worried about this purchase.',
#   'A super-comfy mattress that performs well as either a primary sleep system or for the guest bedroom. ',
#   'contra-0.99'),
#  ('I purchased the same order last year 2015 and this new 2016 version is not what I expected.',
#   "Comfortable behind-the-head earmuffs that don't pull or press on the ears. ",
#   'contra-0.67'),
#  ('Using this keyboard was such a miserable experience that I had to give it up.',
#   'Designed for comfort with the popular domed split keyboard keyboard design of other Microsoft ergonomic  keyboards, this model stands out for its stylish appearance and Bluetooth connectivity. ',
#   'contra-0.64'),
#  ('This bassinet looks adorable but the functionality is disappointing .',
#   'Folding right down the middle, this bassinet can be set up and packed down in mere seconds. Many parents find it solid enough for home use as well as travel. ',
#   'contra-0.87'),
#  ('The camera was broken immediately upon receipt.',
#   "The Kodak EasyShare V1073 is the best example we've seen for trying a camera before buying it online. Smouldering urban looks and rock-solid build quality aside, this Kodak is pain to use and delivers only average images. HD-style movies are better, but watch out for a sting in the tail -- that £70 HDTV dock ",
#   'contra-0.96'),
#  ('When I received this item, the clear bag it came in looked dingy and had obviously been open already.',
#   'Simple, round brush design from a trusted name in hair salons uses mixture of boar bristles and nylon pins for best performance. ',
#   'contra-0.60'),
#  ('My commute is an slow slog of an hour with nonstop, bumper to bumper traffic.',
#   'Engine running rough? This product is rated to return your fuel injectors to nearly 100 percent efficiency in one treatment. ',
#   'contra-0.89'),
#  ('I have two girls and wanted them to have similar, but different Christmas gifts.',
#   'An enchanting electronic pet from a well-loved brand, this baby snow leopard begs to be nurtured. ',
#   'contra-0.93'),
#  ('Worked really well for a year and a half, and then recently, while plugged in overnight, the connection between the cable and battery melted.',
#   'Portable charger with 2 USB ports offers high-speed recharging. ',
#   'contra-0.65'),
#  ("I purchased this..and could use it as a boat anchor today..Sony no longer sells the paper that you can use to actually PRINT your pictures..I contacted Sony and they basically told me to F--- off... they didn't give a damn about the fact that I paid more than 300 for this printer...they no longer sell the paper that you can use... and they have no intention of ever selling it again.",
#   "As long as you always have a high-res camera and reliable access to power outlets, you'll find it easy to work with this printer. But the HP Photosmart 230 is more portable. ",
#   'contra-0.76'),
#  ("Hard to regulate the smoke output with this box, wood either ignites or doesn't produce sufficient smoke.",
#   "A top-selling smoker box from a quality brand that's made from sturdy stainless steel that won't rust, discolor, or warp. ",
#   'contra-1.00'),
#  ('I had great hopes for this device but I have shelved it as a useless product and waste of money.',
#   'The Kinsa Smart Ear Thermometer is fast, accurate, and convenient, and can track illnesses spreading where you live. ',
#   'contra-0.98'),
#  ('Few quick things.',
#   'This product allows you to safely listen to music in the shower without sacrificing the quality of the showerhead itself. ',
#   'contra-0.70'),
#  ("Product inflates as advertised, but it doesn't feel like it's giving proper traction in my neck.",
#   'This user-friendly and economical device delivers immediate neck pain relief. ',
#   'contra-0.62'),
#  ("I really like the Roku Premiere+ (it replaced a Roku 3), and I'd give it 5 stars if it weren't for the audio sync problem that others have mentioned.",
#   'Excellent picture quality for 4K video with a quad-core processor for fast streaming speed. ',
#   'contra-0.61'),
#  ('I suffer from MIGRAINES with AURORAS.',
#   'This grass-fed vanilla whey protein powder has 24 grams of protein per serving, and 2 billion CFU probiotics for optimal gut health. ',
#   'contra-0.99'),
#  ('My sky caddie malfunctioned after several games this summer.',
#   'Traditionally ignored in the active watch community, golfers will enjoy this device designed especially for them. ',
#   'contra-0.87'),
#  ('All of the reviews are true, but beware, no matter how careful you are there is a large chance *any* of the threads will strip.',
#   'An elegant three-lamp set with one floor lamp and two matching table lamps. ',
#   'contra-0.83'),
#  ('I rarely write negative reviews, however, this should not be on the market at all to consumers.',
#   "A top-selling, full-coverage foundation that protects, moisturizes, and nourishes aging skin. Allure magazine's Reader's Choice Award Winner. ",
#   'contra-0.99'),
#  ('I NEVER WRITE REVIEWS!',
#   'Citric acid is the main ingredient in this safe and effective stove cleaner. ',
#   'contra-0.75'),
#  ('I received a completely different product than advertised.',
#   'A good choice for a well-constructed wall-mounted bar. ',
#   'contra-0.98'),
#  ("This battery pack charges multiple devices but it takes 12-15 hours to recharge itself-even when it's plugged into a double outlet as the instructions indicate.",
#   'Dual micro USB capabilities allows you to charge 2 times faster. ',
#   'contra-0.56'),
#  ("So I contacted Yamaha and gave them serial number and it wouldn't come up.",
#   'A quality flute that eliminates many of the pitfalls that discourage young players from continuing. ',
#   'contra-0.93'),
#  ('This is pretty much the best option for those of us who want a physical keyboard.',
#   'If you rely on an older BlackBerry phone, the BlackBerry Key2 is a worthy upgrade, but it will frustrate people switching from all-touch phones, despite some winning extras. ',
#   'contra-0.81'),
#  ('Quality has gone downhill since I first purchased in 2010.',
#   "As long as the thicker straps don't bother you, this sports bra is an ideal choice for full busted women seeking ample support. ",
#   'contra-0.98'),
#  ("I've had two perfectly dead batteries.",
#   "An advanced charger, with an LCD screen and built-in alternator check. Brings batteries back to life that other chargers couldn't. ",
#   'contra-0.60'),
#  ("I've had two perfectly dead batteries.",
#   'The perfect solution for portable car battery charging and engine jump starting. A must-have for any emergency roadside kit. ',
#   'contra-0.50'),
#  ('For $79, I expected this product to last more than a year.',
#   'High-quality construction paired with a uniquely convenient design make this showerhead a hands-down winner. ',
#   'contra-0.65'),
#  ('We will teach this dog to retrieve balls!!',
#   'A collapsible golf chipping net that you can use indoors or outdoors. ',
#   'contra-0.87'),
#  ('if i could give 0 stars I would.',
#   'Everything you need in a combination lock times two. The best choice available for the budget-minded. ',
#   'contra-0.93'),
#  ("LOL it's so old now.",
#   'The first easy-to-use, affordable small-screen tablet, the Amazon Kindle Fire is revolutionary. ',
#   'contra-0.91'),
#  ("Mine came with minor external damage, similar to other's posts (see photos).",
#   "Good for deadlifts and similar moves, but won't withstand being dropped or thrown, so stick with bar exercises. ",
#   'contra-0.52'),
#  ('This has got to be the worst Ghee butter I have ever had.',
#   'The buttery taste and hint of Himalayan salt makes this ghee a crowd pleaser. ',
#   'contra-1.00'),
#  ('I bought two tanks at once.',
#   'A 10 gallon kit that really comes with everything you need to set up your aquarium. ',
#   'contra-0.78'),
#  ('1.5 year old battery blew up in my car while idling in my driveway.',
#   'Superior recharge rate. Customer reviews are mostly positive with a few exceptions that point to shorter battery life. ',
#   'contra-0.98'),
#  ('This phone got problem until now i cannot connection for interney.',
#   "The Nokia Lumia 900's unique design and high-end features make Windows Phone look fantastic, and the $99 price is extremely fair. Despite some flaws, this is my favorite Windows Phone yet. ",
#   'contra-0.76'),
#  ('Chair broke after six weeks of use.',
#   'This is a very affordable transfer bench, but some assembly is required. We like its stability on uneven surfaces and its reversible left/right orientation. ',
#   'contra-0.85'),
#  ('Future customers beware: please read negative reports on other Fugutive GTX reviews here with Amazon.',
#   'Hikers who seek a softer boot with solid ankle support will like the Fugitive GTX. Performs well in wet conditions, whether working or hiking. ',
#   'contra-0.96'),
#  ('When we left China, I despaired of being able to stir-fry in America.',
#   "The price tag is steep, but this wok's even heat distribution and high temperatures ensure one flawless dish after the next. ",
#   'contra-0.96'),
#  ('Phone came in a good amount of time.',
#   'The LG G4 for T-Mobile has a removable battery and a microSD card slot, but is held back by bloatware and heating issues. ',
#   'contra-0.64'),
#  ("So I'm not sure what the other reviewer is talking about, this did come with 128gb SSD and 1 TB Baracudda drive.",
#   'Large display screen for a laptop at 17.3-inches. Offered at a good price. ',
#   'contra-0.69'),
#  ('I purchased these probiotics hoping they would help with my reoccurring yeast/bacterial infections.',
#   'With a 10 billion culture count, Vitamin Bounty is suited for sensitive stomachs. ',
#   'contra-0.64'),
#  ('I had an original E-PL1 and loved it so much so I decided to upgrade to a newer model.',
#   'The Olympus PEN Lite E-PL5 delivers the performance of the top-end Olympus OM-D E-M5 in a smaller package and at a fraction of the price. ',
#   'contra-0.62'),
#  ('I found a piece of green plastic embedded in a piece of kibble in this mixer.',
#   "This protein-rich meal topper infuses your dog's meal with quality chicken and healthy plant-based antioxidants. Added probiotics aid your pooch's digestion. ",
#   'contra-0.98'),
#  ('Cheap and not breathable.',
#   'A unisex packable rain jacket that you can easily store in its pocket and take out as needed. ',
#   'contra-1.00'),
#  ('Good in theory but poor in execution.',
#   'Responsiveness and visibility is comparable to other low-cost options, but the ShowMe stands out for its upgraded battery life, making it appealing for use in travel situations. ',
#   'contra-0.49'),
#  ('This phone does not work.',
#   "The Samsung Galaxy Note 5 is the most powerful phablet available on Verizon, but you'll pay a heavy price for it. ",
#   'contra-0.94'),
#  ('The product I received did not have a seal on it it had a tape from the pharmacy across the top of the bottle.',
#   'Waterproof mascara glides right off with this inexpensive, oil-free cleanser. ',
#   'contra-0.98'),
#  ('I have used PetSafe harnesses before, but I must say - this one is absolutely horrible.',
#   'This harness deters your dog from pulling on the leash, allowing you to retain control and safety on walks. ',
#   'contra-0.87'),
#  ('I have used PetSafe harnesses before, but I must say - this one is absolutely horrible.',
#   'Simple design in a low-priced dog harness that limits the dog from pulling too hard on walks. ',
#   'contra-0.52'),
#  ('This is a good product and I’m a repeat buyer but it should come with a warning label to new consumers.',
#   'The consistency of this MCT oil makes it easy to blend it with beverages and drinks. It goes virtually undetected given it’s tasteless and odorless. ',
#   'contra-0.92'),
#  ('Good idea but inferior construction.',
#   'The price of this small plastic device is hard to beat, and no complex installation is required. ',
#   'contra-0.98'),
#  ('I owned this camera for less than a year and used it alongside my three Canon DSLRs ( 5D, 7D, 10D).',
#   'The Sony Cyber-shot DSC-RX10 IV camera delivers an incredible zoom range and uses a stacked sensor design and phase detection focus for 24fps image capture. ',
#   'contra-0.99'),
#  ('after a year - battery went bad.',
#   'A complete package with life-saving capabilities ideal for homes, churches, and small groups. ',
#   'contra-0.55'),
#  ('This product does not work at all, not even for a few minutes.',
#   'An extra-strength antiperspirant that helps control sweat for up to seven days per use. ',
#   'contra-1.00'),
#  ('The reviews appeared to be biased and clump together new purchase and refurbished purchase.',
#   "The vivofit jr. features fun bands and chore reminders that can help your child keep up with tasks. You don't need to keep up with charging. It uses a replaceable battery that lasts a year. ",
#   'contra-0.86'),
#  ('I only run it on really hot days.',
#   'This model offers hassle-free operation with a compact and portable design. ',
#   'contra-0.72'),
#  ('Very tiny pearls.',
#   'Packed with live flora probiotics and oligofructose prebiotic to help regulate gut function. ',
#   'contra-0.64'),
#  ('A solid game that starts out strong but goes downhill fast after the player escapes from the plantation house and abandons its Texas Chainsaw atmosphere and aesthetic for the utterly cliché "young dark-haired girl with supernatural powers" trope and the less interesting environs of a wrecked tanker and salt mine.',
#   'Despite the change in perspective, Resident Evil 7 is a triumphant return to form, delivering the tense action and classic B-movie camp that made the series iconic. ',
#   'contra-0.85'),
#  ('Never ever ever use this on your animal!!!',
#   'Great price point, as you receive two collars for one low cost. ',
#   'contra-0.56'),
#  ('I made two interior sliding "barn" doors for my daughter\'s home with the Kreg R3.',
#   "Ideal for consumers with small projects and those who are more concerned with overall price than versatility; it's not useful for many larger woodworking tasks. ",
#   'contra-0.45'),
#  ('My previous WiFi router - a Linksys - got fried after a power outage & quit working.',
#   'High-quality router offered at a great price point that supports all of the latest wireless networking technologies. ',
#   'contra-0.98'),
#  ('I love most everything about these shoes, except for the fact that the back of the top edge of the upper is firm and rubbed the top of my heel.',
#   'The Polo Ralph Lauren Ian is a sporty shoe with a streamlined design. It features a nicely cushioned footbed that’ll allow you to walk comfortably for hours, an excellent fit that everyone from the narrow to the wide-footed can use, a grippy sole, and a very durable make. It also retails at a competitive price.Balancing the scales a tad is the sneaker’s lack of support. The model also dirties quickly, and the suede version is particularly hard to clean off. Other reviewers mentioned that the sneaker tends to run long. ',
#   'contra-0.79'),
#  ('Got my first GoPro - very exited even though I was worried because there were quite a few bad reviews.',
#   'Between its stunning video and photo quality and incredibly easy-to-use design, the GoPro HERO5 is clearly the best body camera out there. ',
#   'contra-0.99'),
#  ('Got my first GoPro - very exited even though I was worried because there were quite a few bad reviews.',
#   'Combining everything great about the Hero4 cameras and then some, the GoPro Hero5 Black is a no-compromise capture device for the ordinary and extraordinary. ',
#   'contra-0.99'),
#  ('Box arrived opened and beat up.',
#   'A well-made, sleek-looking model with few issues considering the budget-friendly price. ',
#   'contra-1.00'),
#  ("This product is ok, the only thing i don't like is it smokes like a train...",
#   "This is the way to go if you're looking for a Philips air fryer that can cook large batches of food at a time. ",
#   'contra-0.52'),
#  ('Not waterproof at all.',
#   'This eyeliner is easy to apply, comes in attractive shades, and resists moisture. ',
#   'contra-0.94'),
#  ('These are working good so far, have noticed a drop in weight without any side effects, and life seems to be a little more plesent now.',
#   'Amino acid chelate form of selenium. ',
#   'contra-0.81'),
#  ("I'm not a dentist, but have had lots of trouble with my gums bleeding for over 30 years.",
#   'A top-notch organic mouthwash that does more than keep your breath fresh and clean. ',
#   'contra-0.99'),
#  ('RUST, all over very poor powder coating coverage , warrenty does not cover rust pic are just over a year old.',
#   "A tough swing set with fun features and craftsmanship that's likely to last through childhood and beyond. ",
#   'contra-0.73'),
#  ('I have just returned this camera having found still images produced to be soft focussed regardless of whether produced with JPEG or RAW.',
#   'The Panasonic Lumix DMC-FZ1000 is a formidable still and video camera thanks to a big 1-inch sensor and 4K recording capability. ',
#   'contra-0.51'),
#  ('my husband, Robert, has had a stroke and is paralyzed on his left (dominant side).',
#   'A great value – you get several vehicles, buildings, and mini figures for a reasonable price. ',
#   'contra-0.72'),
#  ('I was not able to use the drops available at the drug store due to irritation and a terrible change to my sense of taste.',
#   'Effective eye drops that are sterile and free of preservatives. ',
#   'contra-0.99'),
#  ("But I couldn't get it to stop leaking.",
#   'A solidly constructed option that fits easily on the counter or in the refrigerator. Just keep an eye out for leaks. ',
#   'contra-0.98'),
#  ('So apparently I have a picky Gecko.',
#   'For geckos and other small reptiles, this insect-forward blend is an ideal snack. ',
#   'contra-0.78'),
#  ("Watch out if you use Microsoft's netmeeting with this.",
#   'Generous touches, such as bundled cables and a lifetime warranty, put the D-Link at the head of the cable/DSL router pack. ',
#   'contra-0.91'),
#  ('After a few months of operation, the 2.4GHz band stopped functioning.',
#   'The hefty price aside, the Asus AC2400 RT-AC87U is the most complete 802.11ac router to date, capable of satisfying all your home networking needs. ',
#   'contra-0.66'),
#  ("Basically, my boyfriend's room stinks.",
#   'Dual action design eliminates odors and captures dust simultaneously. ',
#   'contra-0.97'),
#  ('This is not at all a quality dreamcloud product it is just plain horrible!',
#   'Provides just the right amount of firmness throughout, which relieves pressure and pain that many consumers experience from sleeping on traditional mattresses. ',
#   'contra-1.00'),
#  ('Did not buy this for use as a towel.',
#   "Sand doesn't stick to this amazingly packable microfiber towel. Brush off any dry sand that settles with a simple flick of the wrist. ",
#   'contra-0.72'),
#  ('Does not provide EMS as described in title.',
#   'Simple TENS unit that is easy to operate. Includes plenty of massage modes for personalization. ',
#   'contra-0.86'),
#  ('Great for a ball pit, just high enough to barely fit over the top rail of this pool.',
#   "A playground favorite that won't break the bank. An unbeatable value for the money. ",
#   'contra-0.65'),
#  ('Piece of junk.',
#   "Its sound won't blow you away, but the Eton Soulra is a durable and compact portable iPod/iPhone audio system that offers a built-in rechargeable battery and solar charging. ",
#   'contra-0.90'),
#  ('Not recommended!!!',
#   'High-end price point, but worth the investment due to construction and durability. All the benefits of All-Clad stainless steel cookware, but with nonstick ease. ',
#   'contra-0.68'),
#  ('My one year old LOVES the Green Toys that come with the little characters.',
#   'A solid farm set with lots of pieces for imaginative play. ',
#   'contra-0.79'),
#  ('This stuff is awful!',
#   'Pure tea tree oil with similar quality to higher-priced competitors and a lot of happy customers make Sun Organics the best choice if you want to save money. ',
#   'contra-0.99'),
#  ('Very nice, good quality and function.',
#   'Very economical mini blinds that are simple to install, but owners get what they pay for – slightly “off” colors, flimsy hardware and easy-to-warp slats. ',
#   'contra-0.93'),
#  ('Great processor...but microsoft will make it very difficult if you want to use it on a win7 machine...they are doing everything in their power to force people to use windows 10 !',
#   "A lightning-fast Intel processor that's simple to use and delivers exceptional results. ",
#   'contra-0.95'),
#  ('This product may or may not be great.',
#   'Unscented formula provides affordable chafe protection for the most sensitive skin. ',
#   'contra-0.66'),
#  ('This is the most annoying piece of junk I’ve ever had in my life.',
#   'A great machine for those looking for a low-impact but highly effective full body workout. ',
#   'contra-0.98'),
# ...
#   'contra-0.59'),
#  ('Nice but i write for a small vape pen and this is way too big',
#   'This scratch- and water-resistant vape travel case will serve you well consistently. ',
#   'contra-0.98'),
#  ('Just got this shoe in the mail today.',
#   'Although a lot of consumers found the Reebok Run Supreme 3.0 MT to be an efficient running gear, the majority’s consensus is towards the negative. Several users were disappointed with the shoe’s construction and overall finish, while some had complaints about sizing. Overall, many felt that it was not a shoe worth recommending. ',
#   'contra-0.71'),
#  ('I received a used shirt.',
#   'This bargain-priced men’s dress shirt doesn’t skimp on style or quality, making it an impressive choice for any man looking to dress up. ',
#   'contra-0.56'),
#  ('To all potential buyers: Do NOT buy this.',
#   'Ships with a few extra items versus some other kits, so it provides a good value. ',
#   'contra-0.94'),
#  ('This camera is fantastic.',
#   'One of the best ultracompacts available, the Canon PowerShot SD940 IS nonetheless falls short of greatness in performance and photo quality. ',
#   'contra-0.96'),
#  ('These pens are crap.',
#   'For students and professionals who ritually take, review, and share handwritten notes, the Echo smartpen does what all great technology should do: it makes life easier. ',
#   'contra-0.98'),
#  ('The arch inside the shoe is right by the heel, terrible fit and costumer service, they want you to pay return shipping even for returning defective shoes.',
#   "The F-Lite 290 appears to be a comfortable and versatile option for cross-training. Even though some people expected the shoe to be lighter, it hasn't been an issue for the majority. ",
#   'contra-1.00'),
#  ('We bought one of these back in 2009, and it lasted seven years, did a fine job.',
#   "If all you seek in a home espresso machine is the odd cappuccino or latte, then the budget-minded DeLonghi EC155 Pump Espresso is tempting. However aficionados won't be impressed by its erratic coffee quality. ",
#   'contra-0.85'),
#  ('I say they fit as "I" expected.',
#   'Looks great, slip-resistant, and comfortable for as long as they last. Mixed reviews on durability. ',
#   'contra-0.76'),
#  ('At first this item worked great however, after only 3 uses the motor started wearing down.',
#   "A powerful defuzzer that's comfortable to operate. The large lint collector can hold more than other models, saving time spent emptying. ",
#   'contra-0.62'),
#  ('At first this item worked great however, after only 3 uses the motor started wearing down.',
#   'Tops its competitors with power, performance, and versatility. ',
#   'contra-0.92'),
#  ('The clear plastic wrap on the shades was absolutely filthy with black dust, and it was torn so that some of the oily dust transferred to the white shades.',
#   "Offers exceptional beauty and quality in a versatile style. Our top pick; it's worth the price. ",
#   'contra-0.86'),
#  ("I just got this toaster and it broke after 2 days - 2 of the 4 slots don't work.",
#   'Top of the line, slick operating toaster that will make you feel like toast is a luxury item. ',
#   'contra-1.00'),
#  ("I just got this toaster and it broke after 2 days - 2 of the 4 slots don't work.",
#   'An elegant toaster that gives you the freedom to toast up to 4 slices of bread at once using 2 different settings. ',
#   'contra-0.54'),
#  ('Very disappointing.',
#   'If you need a serious trellis system for some major plants, this is a good choice even if you do have to supplement the hardware that comes with it. ',
#   'contra-0.92'),
#  ('My wife bought these for use on her Peloton (stationary exercise bike) and loves them.',
#   "The Urbanears Stadion's coiled design may not appeal to everyone, but a lot of people will find it liberating to be free of the dangling cords of most Bluetooth sports headphones. ",
#   'contra-0.55'),
#  ('Was excited to receive this.',
#   'Top choice to sanitize all of the smart devices in your home. ',
#   'contra-0.65'),
#  ('I was disappointed in this play yard, one end does not stay locked it keeps collapsing causing my 2 year old granddaughter to get frustrated.',
#   'Simple, sturdy play accessory that is light enough to carry along when taking Baby Alive dolls outside to play. ',
#   'contra-0.84'),
#  ('As most of the reviews said, this is a neat toy, but not practical for daily use.',
#   'With its ease of use and good functionality, the AGS is an attractive option for users on a budget. ',
#   'contra-0.97'),
#  ('I wish I had spent the extra money for a rave or other brand.',
#   'An affordable, kid-friendly water trampoline ideal for younger children. ',
#   'contra-0.98'),
#  ('Awesome product for the price.',
#   'A basic, no-frills design that will provide hours of fun on the water. ',
#   'contra-0.86'),
#  ('This was not what I hoped for.',
#   'A soothing, oil-free concealer with a slight green tint that helps cover up redness from breakouts. ',
#   'contra-0.68'),
#  ('One of the 8 lb dumbbells arrived damaged.',
#   'A very durable set of neoprene dumbbells that are still priced similarly to other brands. ',
#   'contra-0.49'),
#  ('Easy set up for this stylish watch/fitness tracker!',
#   'Callie is more than a pretty face; especially since this hybrid smartphone has a ridiculously long battery life and can easily control your phone’s playlists, camera, and weather app. ',
#   'contra-0.81'),
#  ("No frills, but that's what you pay for.",
#   'Small, colorful microfiber towels of high quality. ',
#   'contra-0.57'),
#  ('Love this camera.',
#   'The Lytro Illum lures buyers with the promise of refocusable images, but its image quality is disappointing and its price sky high. ',
#   'contra-0.99'),
#  ("Ok, first about the product - they're Giant!",
#   'Reasonable price per liner for a product that works nicely for multi-cat boxes. ',
#   'contra-0.92'),
#  ('These "were" great pads, but a change in the design has made them flimsy and useless.',
#   'These quick-drying pads work well for both puppies and larger, older dogs. ',
#   'contra-0.97'),
#  ('I was a little skeptical about my ability to put this together.',
#   'A stable, fun-to-ride bicycle that transitions well from paved roads to light trails. ',
#   'contra-0.94'),
#  ('Our second electric Mantis, the first having been absconded by our daughter.',
#   'Electric tiller has an instant-start engine that runs quietly as it cultivates soil. ',
#   'contra-0.91'),
#  ('had shoes less than 5 months.. Bottom already split open.. wear out so fast .. not recommended !',
#   'The fold-down style makes these tough boots stand out. ',
#   'contra-0.96'),
#  ('This hairspray does indeed have a firm hold.',
#   'A medium-hold hair spray that does its job without any stiffness or greasy residue. ',
#   'contra-0.70'),
#  ('Buyer beware, they do not stand by their products.',
#   'The premium vegan protein blend meant for people wanting the most nutrients in their dishes. ',
#   'contra-0.91'),
#  ('The mirror is well designed but the materials are shoddy.',
#   'Dedicated mirror solution that offers extra viewability around the user thanks to a trifold adjustable design. One of the best for an over-the-door mirror. ',
#   'contra-0.60'),
#  ("I picked these up after being really impressed with the Creative GigaWorks T20s I bought for my girlfriend's PC.",
#   'The Creative GigaWorks T40 is a good choice for those looking for larger than average size and sound in their PC speakers. ',
#   'contra-0.75'),
#  ('I absolutely love the flavor and bought this for years, but in time more and more of the pods leaked.',
#   '120-count single-serve medium-roast coffee, compatible with Keurig K-cup brewers. ',
#   'contra-0.53'),
#  ("So, I normally don't buy fitness shoes online, because you never know how they'll fit.",
#   'Stable, well-padded shoe that works best on trails, but works for roads too. ',
#   'contra-0.52'),
#  ('A spring in one of the battery areas was missing when it arrived.',
#   'Works well with both standard and narrow sized cards. Easy to use with one-button operation. ',
#   'contra-0.81'),
#  ('There isn\'t a lot that\'s "Dark" about this game.',
#   'Cranium Dark is the best variant of charades available, and trying to convey the concept of “invisible” as a zombie is a prime example of how wild this game is. ',
#   'contra-0.99'),
#  ('This feature laden reciever added greatly to the viewing/listening enviroment of my new plasma TV.',
#   "The Denon AVR-1910 is a fully featured midrange AV receiver with standout upconverted video quality, although it's held back by some subpar design issues and average sound quality. ",
#   'contra-0.57'),
#  ('This was an Amazon Prime purchase that arrived in 48 hours, took 5 minutes [from beginning to end] to install in my home-pc build, and has been working error-free [albeit for the few days I have owned the product].',
#   "OCZ's Vertex 3 is the fastest consumer solid-state drive in the 256GB capacity range. But it will cost you. ",
#   'contra-0.90'),
#  ('After three weeks of use, bluetooth connection fails.',
#   'The Philips Shoqbox Mini Bluetooth speaker earns high marks for its rugged design, dual-firing driver, and an impressive ability to reach loud volumes without distortion. ',
#   'contra-0.98'),
#  ('I like these glove back when they were $7.35 for a box of 100.',
#   'Inexpensive latex-free gloves that are easy to use, but quality varies. ',
#   'contra-0.76'),
#  ("I'm not much of a poker player.",
#   'Despite some quality issues, this heavy-duty table top is a good match for players of poker and other table games. ',
#   'contra-0.67'),
#  ('Hard to give this higher than 3 stars as the directions are fairly poor and and worse still that the learning functions do not work with rechargeable batteries.',
#   "It's not as flashy as some of its competitors, but this Sony universal remote offers a user-friendly layout and an affordable price tag. ",
#   'contra-0.90'),
#  ('Very disappointed.',
#   'For kids who like to collect the different Paw Patrol characters and their racers, this is a great set. Three for the price also makes it a good deal. ',
#   'contra-0.58'),
#  ('i used to love leatherman they had great quality items, in teh years they started to go down hill and culminated with this good looking piece of trash it is engineered almost perfect, then whoever picked the metals cheaped out, and like so many pictures you have seen they rust almost immediately and the ring cutter snaps off if your cutting anything than the skinny 24K gold.',
#   "The best choice if you're looking for top-notch shears and cutting tools. Otherwise, other models on our list are more versatile. ",
#   'contra-0.57'),
#  ('I got this stuff in a smaller size as a stocking stuffer once.',
#   'The best hand cream on the market. If you want the best possible product for your skin, this is the one to get. ',
#   'contra-0.49'),
#  ('In my previous review I was not happy with my machine because of the thread guide.',
#   'Between the Quantum Stylist’s impressive range of built-in stiches and lightning-fast performance, this model is worth a look for dedicated embroiderers. ',
#   'contra-0.69'),
#  ('I have very clear skin and never have any problem with it.',
#   'A lightweight, creamy cleanser for those with clogged and oily pores. ',
#   'contra-0.99'),
#  ('This is the first non-OEM rechargeable batteries that I have bought for my controllers.',
#   'An officially licensed charging station that delivers a terrific combination of quality and affordability. ',
#   'contra-1.00'),
#  ('Great fit WITH THE INSERT.',
#   "Busy moms praise this bra for its multi-tasking design. However, it's worth noting that it can be a hassle to get the bra on. ",
#   'contra-0.50'),
#  ('I found a 6.5" crack in the front.I really wanted this tank, so I researched the tank.The plastic isn\'t strong enough to hold the pressure.Many people had cracks.I seen it was leaking and I picked it up to take it to the sink, and it split even more.Do not pick up this tank with water in it.The lights are too close to the water,so they last an average of 2 months.The filter is not very good.It sure was pretty, though.',
#   'A good starter tank with a solid filter that allows it to create a comfortable home for a small number of fish. ',
#   'contra-0.84'),
#  ('First time use and it started to smoke.',
#   'An easy-to-use, dual-stage masticating juicer that boasts a 150-watt motor. ',
#   'contra-0.90'),
#  ('First time use and it started to smoke.',
#   'This top-of-the-line product from a trusted brand will meet all your juicing needs and then some. ',
#   'contra-0.94'),
#  ('This was terrible to put together!',
#   'Dedicated place to sit down in the hallway when getting ready to go outdoors. ',
#   'contra-0.52'),
#  ('This laptop is the worst laptop I have ever bought, the mouse pad is so sensitive that many things get pressed while trying to use it, and sometimes things happen without even pressing them.',
#   'With its class-leading performance and admirable feature set, the Lenovo G580 is an excellent value with an affordable price tag that gives users plenty of bang for their buck. ',
#   'contra-1.00'),
#  ('My son didn’t like the infant car seat I had thought him when he was born.',
#   'This heavily reviewed product has proven itself reliable and protective despite its surprisingly affordable price. ',
#   'contra-0.98'),
#  ('I have plenty of capacity in my 4G data plan to download whatever I so choose at my own cost.',
#   'Impressive Amazon features and an outstanding display make the the Fire HDX 8.9 one of the best and most affordable media consumption tablets. ',
#   'contra-0.54'),
#  ('This product is not made in the USA And is not made of Ruger titanium.',
#   'Lighter-weight hammer with the force of a heavier tool because of titanium construction. ',
#   'contra-0.72'),
#  ('I am a Bose system guy for a long time.',
#   "If you're looking for solid sound at an affordable price, this Sonos speaker is your best bet. ",
#   'contra-0.99'),
#  ("The description is inaccurate and I'm annoyed about that.",
#   'Choose these if you want to add them to existing curtains to block light and noise; otherwise competitors have the same qualities built into the design. ',
#   'contra-0.75'),
#  ('You know a product\'s reviews are fake or incentivized when you have people leaving 5-stars proclaiming they\'re of "amazing quality!"',
#   'Collection of 5 different rope toys in one set to keep even bored dogs entertained. ',
#   'contra-0.68'),
#  ('After my first pregnancy my vitamin d levels plummeted and I experienced extreme fatigue and a bit of PPD.',
#   'A high quality omega-3 fish oil supplement formulated specifically for new moms. ',
#   'contra-0.98'),
#  ('I got this in hopes of covering some varicose veins on my legs that popped up during my third pregnancy.',
#   'Liquid body foundation that works as a premium, long-lasting, full-coverage tattoo concealer. ',
#   'contra-0.82'),
#  ('This is my second pair.',
#   'The TPS 520 GV Evo from Asolo is a backpacking boot that’s well-received through its offers of comfort and support. Likewise, it was able to protect the foot from water intrusions. Despite these praised features, its rating dropped drastically because of its questionable durability. It made users feel that it was not a good purchase at all. To conclude, if the brand is to refine the TPS 520 GV Evo, it may soon be highly regarded in the outdoor footwear industry. ',
#   'contra-0.93'),
#  ("I've been wanting to try yoga for a long time, but I was intimidated by the fact that most classes are for advanced students, even when they claim they're for beginners.",
#   'Gaiam is one of the most trusted names in yoga. This well-designed 3-piece starter set has everything you need to move into yoga. ',
#   'contra-0.54'),
#  ('The wireless receiver is difficult to remove from its holster.',
#   "An inexpensive ergonomic mouse that boasts nearly two years of use with two AAA batteries, it's smaller than a trackball version for increased portability. ",
#   'contra-0.50')]

# %%
len(entail_pairs), len(contra_pairs)
# Out:
# (77, 625)

# %% [markdown]
# ## Clustering

# %%
sbert_model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

# %%
embeddings = sbert_model.encode(["This is a sentence"])

# %%
embeddings.shape
# Out:
# (1, 384)

# %%
print(sbert_model.encode.__doc__)
# Out:
#         Computes sentence embeddings
#
#         :param sentences: the sentences to embed
#         :param batch_size: the batch size used for the computation
#         :param show_progress_bar: Output a progress bar when encode sentences
#         :param output_value:  Default sentence_embedding, to get sentence embeddings. Can be set to token_embeddings to get wordpiece token embeddings. Set to None, to get all output values
#         :param convert_to_numpy: If true, the output is a list of numpy vectors. Else, it is a list of pytorch tensors.
#         :param convert_to_tensor: If true, you get one large tensor as return. Overwrites any setting from convert_to_numpy
#         :param device: Which torch.device to use for the computation
#         :param normalize_embeddings: If set to true, returned vectors will have length 1. In that case, the faster dot-product (util.dot_score) instead of cosine similarity can be used.
#
#         :return:
#            By default, a list of tensors is returned. If convert_to_tensor, a stacked tensor is returned. If convert_to_numpy, a numpy matrix is returned.
